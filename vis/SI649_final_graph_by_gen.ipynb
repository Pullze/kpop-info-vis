# %% [markdown]
# ## Graph of 2nd generation's group number and released MV

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/Pullze/kpop-info-vis/refs/heads/master/data/app_kpop.csv')

# %%
# df.info()

# %%
# df.to_csv('app_kpop.csv', index=False)

# %%
# df['releasedate'] = pd.to_datetime(df['releasedate'])

# %%
# df['year'] = df['releasedate'].dt.year

# %%
# # Sort the DataFrame by 'id_artist' and 'releasedate'
# df_sorted = df.sort_values(by=['id_artist', 'releasedate'])

# # Keep only the first row for each 'id_artist' which represent the debut song of each artist
# df_first_release = df_sorted.drop_duplicates(subset='id_artist', keep='first')

# %%
# num_artist = df_first_release.pivot_table(index='year', values='id_artist', aggfunc='count').reset_index()

# %%
# num_artist = num_artist[num_artist['year'] >= 1996]

# %%
# num_artist.to_csv('graph_by_gen.csv', index=False)

# %% [markdown]
# ## Graph_by_gen
#
# - Title: Number of Debut of K-pop Artists by Year
#
# 1. 1st Generation (1996–2004): Observation: The number of K-pop idols was consistently low during this period, generally below 50 artists per year.
#
# 2.  2nd Generation (2005–2011): There was a significant rise in debuts of K-pop idols around 2010, peaking at approximately 150 artists. The second generation is dubbed the ‘Golden Age of K-Pop’ with the most iconic songs to date
#
# 3. The 3rd Generation (2012-2017) experienced a sharp rise in new idol debuts, surpassing 300 artists by 2015 and maintaining consistently high numbers. This era was defined by the global success of groups such as BTS, EXO, and TWICE, alongside the accelerated commercialization and industrial growth of the K-pop industry.
#
# 4. The 4th Generation (2017-2023) highlights the rise of newer groups with a focus on digital platforms like YouTube and TikTok for global reach.

# %%
num_artist = pd.read_csv('graph_by_gen.csv')

# %%
# Plot the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='id_artist', data=num_artist, marker='o')

plt.title('Number of Debut of K-pop Artists by Year')
plt.xlabel('Year')
plt.ylabel('Number of Artists')
plt.grid(True)
plt.show()

## TODO: can you make the timeline shown by five stages? as we tell the story?
